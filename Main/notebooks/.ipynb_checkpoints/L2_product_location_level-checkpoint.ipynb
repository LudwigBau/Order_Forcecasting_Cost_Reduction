# %% [markdown]
# ## Create Product Location Grid (FILTERED)

# %%
# Libaries
import warnings
warnings.filterwarnings('ignore')
import sys

# Basics
import pandas as pd
import numpy as np
import math 
from itertools import product

# Visualisation
import seaborn as sns
import matplotlib.pyplot as plt

# Geo Data
import pgeocode
from geopy.geocoders import Nominatim

# %%
# Load Dataset (Select B2C Sales)

### ORDER DATA ###
df = pd.read_csv("../data/processed/b2c_orders_clean.csv")
### HOLIDAY DATA ###
holiday_df = pd.read_csv("../data/intermediate/calender.csv")
### WEATHER DATA ### 
weather_df = pd.read_csv("../data/intermediate/weather.csv")

# %%
### GET STATE ####

# define Germany 
nomi = pgeocode.Nominatim('de')

# get state names from zip codes and assign to new column 
df["state"] = nomi.query_postal_code(df["billing_zip"].tolist()).state_name.tolist()

# %%
df.business_type.value_counts()
# Out:
# B2C    5395860
# Name: business_type, dtype: int64

# %%
print(df.state.isna().sum())
print((df.state.isna().sum() / len(df))*100)
# Out:
# 342703
# 6.351221121378242

# %%
df[df['state'].isnull()].head(3)
# Out:
#            date             order_id        order_item_id  \
# 184  2022-03-28  5103674889350632864 -4046019662819641819
# 233  2021-05-15  3486896222173923246  6486245077222367310
# 733  2021-11-28  7051856995147585260  6439824637857445392
#
#              customer_id       order_datetime  quantity  product_variant_id  \
# 184 -5049257674105794573  2022-03-28 15:11:41         1        8.106800e+18
# 233 -5049257674105794573  2021-05-15 20:19:24         1        3.002792e+18
# 733 -5049257674105794573  2021-11-28 16:36:22         2        8.686326e+18
#
#     warehouse_chain  item_discount billing_country billing_zip business_type  \
# 184      WH-Chain-2           4.49              DE       89387           B2C
# 233      WH-Chain-2           0.00              DE       93951           B2C
# 733      WH-Chain-2           9.88              DE       45157           B2C
#
#      filled_prices state
# 184          29.95   NaN
# 233          86.27   NaN
# 733          32.95   NaN

# %% [markdown]
# ## Clean Data
#
# There are some ZIP code that are wrong. Probably a human mistake.
#
# - Check for other missing values
# - Delete values
# - Allign state names
# - Group data according to state - sum quantity
# - Join Weather and Location data
# - Check for correlations

# %%
# Check for missing values 
df.isna().sum()
# Out:
# date                       0
# order_id                   0
# order_item_id              0
# customer_id                0
# order_datetime             0
# quantity                   0
# product_variant_id         0
# warehouse_chain            0
# item_discount              0
# billing_country            0
# billing_zip                0
# business_type              0
# filled_prices              0
# state                 342703
# dtype: int64

# %%
# select non na rows of state
df = df[df['state'].notna()]

# %%
#test 
df.state.isna().sum()
# Out:
# 0

# %%
# Change names 

# From get_weather_data notebook:

# Change names of station names to avoid errors
df['state'] = df['state'].str.replace('-','_')
df['state'] = df['state'].str.replace('ü','ue')
df['state'] = df['state'].str.replace('/','_')

# test
# check if both lists have the same entries
a = df.state.unique().tolist()
b = weather_df.state.unique().tolist()

# test (16 unique states) coorect!
set(a) & set(b)
# Out:
# {'Baden_Wuerttemberg',
#  'Bayern',
#  'Berlin',
#  'Brandenburg',
#  'Bremen',
#  'Hamburg',
#  'Hessen',
#  'Mecklenburg_Vorpommern',
#  'Niedersachsen',
#  'Nordrhein_Westfalen',
#  'Rheinland_Pfalz',
#  'Saarland',
#  'Sachsen',
#  'Sachsen_Anhalt',
#  'Schleswig_Holstein',
#  'Thueringen'}

# %%
# group datasets on date and sum quantity

# Create date column 
df["date"] = pd.to_datetime(df["order_datetime"]).dt.date

# Order: Group by date and state
state_day_sales_df = df.groupby(["date", "state"]).sum()

# %% [markdown]
# ### JOIN

# %%
# Join
def join_all(state_day_sales_df, weather_df, holiday_df):

    # make date index to merge on date 
    weather_df["date"] = pd.to_datetime(weather_df["date"]).dt.date
    weather_df.set_index(["date", "state"], inplace=True)
    
    # Join state and weather
    weather_sales_df = pd.merge(state_day_sales_df, weather_df, left_index=True, right_index=True)


    
    weather_sales_df.reset_index(inplace=True)
    weather_sales_df["date"] = pd.to_datetime(holiday_df.date)
    weather_sales_df.set_index("date", inplace=True)


    holiday_df["date"] = pd.to_datetime(holiday_df.date)
    holiday_df.set_index("date", inplace=True)



    #merge weather_sales_df with holiday_df to get final_df
    final_df = pd.merge(weather_sales_df, holiday_df, left_index=True, right_index=True)

    # Drop columns useless columns
    drop_columns = ["filled_prices", 'order_id', 'order_item_id', 'customer_id',
                    'product_variant_id', 'item_discount', 'station_id']

    final_df = final_df.drop(columns=drop_columns)
    return final_df


final_df = join_all(state_day_sales_df, weather_df, holiday_df)
final_df
# Out:
#                          state  quantity  precipitation_height  \
# date
# 2015-01-01  Baden_Wuerttemberg         3                   0.0
# 2015-01-02              Bayern         3                   0.0
# 2015-01-03              Berlin         3                   0.0
# 2015-01-04             Hamburg         1                   0.1
# 2015-01-05              Hessen         1                   0.0
# ...                        ...       ...                   ...
# 2022-12-27             Sachsen        89                   0.3
# 2022-12-28      Sachsen_Anhalt        49                   0.2
# 2022-12-29  Schleswig_Holstein       150                   0.6
# 2022-12-30          Thueringen        33                   1.5
# 2022-12-31  Baden_Wuerttemberg      1173                   0.0
#
#             sunshine_duration  temperature_air_mean_200  sunshine_duration_h  \
# date
# 2015-01-01            23338.8                    274.65                6.483
# 2015-01-02            22798.8                    274.45                6.333
# 2015-01-03            24361.2                    274.25                6.767
# 2015-01-04            32518.8                    275.05                9.033
# 2015-01-05            38340.0                    278.85               10.650
# ...                       ...                       ...                  ...
# 2022-12-27             9118.8                    280.95                2.533
# 2022-12-28                0.0                    281.15                0.000
# 2022-12-29            15541.2                    282.05                4.317
# 2022-12-30                0.0                    279.95                0.000
# 2022-12-31             1378.8                    280.45                0.383
#
#             suns_classes  temp_classes  rain_classes  is_holiday  ...  \
# date                                                              ...
# 2015-01-01             6             1             0           1  ...
# 2015-01-02             6             0             0           0  ...
# 2015-01-03             6             0             0           0  ...
# 2015-01-04             7             1             0           0  ...
# 2015-01-05             8             4             0           0  ...
# ...                  ...           ...           ...         ...  ...
# 2022-12-27             4             1             1           0  ...
# 2022-12-28             0             1             0           0  ...
# 2022-12-29             6             2             2           0  ...
# 2022-12-30             0             0             4           0  ...
# 2022-12-31             2             1             0           0  ...
#
#             holiday_Erster Weihnachtstag  holiday_Karfreitag  holiday_Neujahr  \
# date
# 2015-01-01                             0                   0                1
# 2015-01-02                             0                   0                0
# 2015-01-03                             0                   0                0
# 2015-01-04                             0                   0                0
# 2015-01-05                             0                   0                0
# ...                                  ...                 ...              ...
# 2022-12-27                             0                   0                0
# 2022-12-28                             0                   0                0
# 2022-12-29                             0                   0                0
# 2022-12-30                             0                   0                0
# 2022-12-31                             0                   0                0
#
#             holiday_Ostermontag  holiday_Pfingstmontag  \
# date
# 2015-01-01                    0                      0
# 2015-01-02                    0                      0
# 2015-01-03                    0                      0
# 2015-01-04                    0                      0
# 2015-01-05                    0                      0
# ...                         ...                    ...
# 2022-12-27                    0                      0
# 2022-12-28                    0                      0
# 2022-12-29                    0                      0
# 2022-12-30                    0                      0
# 2022-12-31                    0                      0
#
#             holiday_Reformationstag  holiday_Tag der Deutschen Einheit  \
# date
# 2015-01-01                        0                                  0
# 2015-01-02                        0                                  0
# 2015-01-03                        0                                  0
# 2015-01-04                        0                                  0
# 2015-01-05                        0                                  0
# ...                             ...                                ...
# 2022-12-27                        0                                  0
# 2022-12-28                        0                                  0
# 2022-12-29                        0                                  0
# 2022-12-30                        0                                  0
# 2022-12-31                        0                                  0
#
#             holiday_Zweiter Weihnachtstag  xmasweek  blackweek
# date
# 2015-01-01                              0         0          0
# 2015-01-02                              0         0          0
# 2015-01-03                              0         0          0
# 2015-01-04                              0         0          0
# 2015-01-05                              0         0          0
# ...                                   ...       ...        ...
# 2022-12-27                              0         0          0
# 2022-12-28                              0         0          0
# 2022-12-29                              0         0          0
# 2022-12-30                              0         0          0
# 2022-12-31                              0         0          0
#
# [2922 rows x 27 columns]

# %%
final_df.to_csv("../data/final/product_location.csv")

# %% [markdown]
# ## SOME EDA

# %%
#Without 0's
correlation = final_df.reset_index()
correlation.set_index(["date", "state"], inplace=True)

pd.DataFrame(np.corrcoef(correlation.values, rowvar=False), columns=correlation.columns)
# Out:
#     quantity  precipitation_height  sunshine_duration  \
# 0   1.000000              0.015080          -0.151918
# 1   0.015080              1.000000          -0.354572
# 2  -0.151918             -0.354572           1.000000
# 3   0.035095             -0.045202           0.278537
# 4  -0.151918             -0.354572           1.000000
# 5  -0.084998             -0.368872           0.950540
# 6  -0.021489             -0.154764           0.385751
# 7   0.036541              0.804113          -0.516809
# 8  -0.002457              0.001691           0.026899
# 9  -0.023628             -0.027883          -0.023406
# 10 -0.004302             -0.012745          -0.021700
# 11 -0.016526             -0.012138          -0.018016
# 12 -0.017746             -0.016389          -0.007078
# 13 -0.008487             -0.014264           0.000175
# 14  0.014714              0.028705          -0.006202
# 15 -0.010844             -0.005913           0.008440
# 16  0.001409              0.014888           0.005582
# 17 -0.014364              0.033715           0.014533
# 18  0.020785             -0.010620           0.020627
# 19 -0.011675             -0.010620           0.002890
# 20  0.000632             -0.005761          -0.000654
# 21 -0.007999             -0.006967          -0.020048
# 22 -0.017053             -0.018667           0.035699
# 23  0.011887             -0.018211           0.006526
# 24  0.023345              0.011538           0.008142
# 25  0.015802              0.003900          -0.028488
#
#     temperature_air_mean_200  sunshine_duration_h  suns_classes  temp_classes  \
# 0                   0.035095            -0.151918     -0.084998     -0.021489
# 1                  -0.045202            -0.354572     -0.368872     -0.154764
# 2                   0.278537             1.000000      0.950540      0.385751
# 3                   1.000000             0.278537      0.182479      0.631844
# 4                   0.278537             1.000000      0.950540      0.385751
# 5                   0.182479             0.950540      1.000000      0.405549
# 6                   0.631844             0.385751      0.405549      1.000000
# 7                  -0.075772            -0.516809     -0.521098     -0.186554
# 8                   0.025999             0.026899      0.033235      0.048098
# 9                  -0.009856            -0.023406     -0.029043     -0.023918
# 17            1.000000        -0.002745            -0.002745
# 18           -0.002745         1.000000            -0.002745
# 19           -0.002745        -0.002745             1.000000
# 20           -0.002745        -0.002745            -0.002745
# 21           -0.000969        -0.000969            -0.000969
# 22           -0.002745        -0.002745            -0.002745
# 23           -0.002745        -0.002745            -0.002745
# 24           -0.007324        -0.007324            -0.007324
# 25           -0.007324        -0.007324            -0.007324
#
#     holiday_Pfingstmontag  holiday_Reformationstag  \
# 0                0.000632                -0.007999
# 1               -0.005761                -0.006967
# 2               -0.000654                -0.020048
# 3                0.008288                 0.007875
# 4               -0.000654                -0.020048
# 5                0.001407                -0.024319
# 6                0.019147                -0.002987
# 7               -0.012446                -0.011091
# 8                0.327329                 0.115590
# 9               -0.005513                -0.001947
# 10              -0.002745                -0.000969
# 11              -0.002745                -0.000969
# 12              -0.002745                -0.000969
# 13              -0.002745                -0.000969
# 14              -0.002745                -0.000969
# 15              -0.002745                -0.000969
# 16              -0.002745                -0.000969
# 17              -0.002745                -0.000969
# 18              -0.002745                -0.000969
# 19              -0.002745                -0.000969
# 20               1.000000                -0.000969
# 21              -0.000969                 1.000000
# 22              -0.002745                -0.000969
# 23              -0.002745                -0.000969
# 24              -0.007324                -0.002586
# 25              -0.007324                -0.002586
#
#     holiday_Tag der Deutschen Einheit  holiday_Zweiter Weihnachtstag  \
# 0                           -0.017053                       0.011887
# 1                           -0.018667                      -0.018211
# 2                            0.035699                       0.006526
# 3                            0.008833                       0.002711
# 4                            0.035699                       0.006526
# 5                            0.039946                       0.012742
# 6                            0.012246                       0.009945
# 7                           -0.026667                      -0.024297
# 8                            0.327329                       0.327329
# 9                           -0.005513                      -0.005513
# 10                          -0.002745                      -0.002745
# 11                          -0.002745                      -0.002745
# 12                          -0.002745                      -0.002745
# 13                          -0.002745                      -0.002745
# 14                          -0.002745                      -0.002745
# 15                          -0.002745                      -0.002745
# 16                          -0.002745                      -0.002745
# 17                          -0.002745                      -0.002745
# 18                          -0.002745                      -0.002745
# 19                          -0.002745                      -0.002745
# 20                          -0.002745                      -0.002745
# 21                          -0.000969                      -0.000969
# 22                           1.000000                      -0.002745
# 23                          -0.002745                       1.000000
# 24                          -0.007324                      -0.007324
# 25                          -0.007324                      -0.007324
#
#     xmasweek  blackweek
# 0   0.023345   0.015802
# 1   0.011538   0.003900
# 2   0.008142  -0.028488
# 3   0.007854  -0.003967
# 4   0.008142  -0.028488
# 5   0.014986  -0.030804
# 6   0.025655  -0.026074
# 7   0.021897   0.002928
# 8   0.105572  -0.022375
# 9  -0.014709   0.369037
# 10 -0.007324   0.374839
# 11 -0.007324  -0.007324
# 12 -0.007324   0.374839
# 13 -0.007324  -0.007324
# 14 -0.007324  -0.007324
# 15 -0.007324  -0.007324
# 16  0.374839  -0.007324
# 17 -0.007324  -0.007324
# 18 -0.007324  -0.007324
# 19 -0.007324  -0.007324
# 20 -0.007324  -0.007324
# 21 -0.002586  -0.002586
# 22 -0.007324  -0.007324
# 23 -0.007324  -0.007324
# 24  1.000000  -0.019539
# 25 -0.019539   1.000000
#
# [26 rows x 26 columns]

# %%
plt.figure(figsize=(15,10))

test = final_df.reset_index()
test = test.set_index("date")
test.groupby('state')['quantity'].plot(legend=True)
